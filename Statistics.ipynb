# %% [markdown]
# ## statistics
# - Ststistics is a mathmatical science pertaining to the collection, presentation, analysis and interpretation of data
# - it is used to understand the complex problem of real world and making it simple
#
# -  Several statistics principle is
#             1)analyzing the Data
#             2)building a statitical model
#             3)predicting the out comes
# ## statical analysis and non statical analysis
# ### statistical analysis
# -    it is the science of collecting, exploring and presenting large amount of data to identify patterns and trainds
# ### Non Statistical analysis
# -  it provides generic information it include text, sound and images
# -  it is also called quantitative analysis

# %%
from IPython.display import Image
Image(filename='D:/images/descritiveStatistics1.png')

# %% [markdown]
# ## Descritive stastics
# -  Descriptive statistics are brief descriptive coefficients that summarize a given data set,
#    which can be either a representation of the entire or a sample of a population
#
# -  Descriptive statistics are broken down into measures of central tendency and measures of variability
# -  Measures of central tendency include the mean, median, and mode,
#
# -  measures of variability include the standard deviation, variance, the minimum and maximum variables, and the kurtosis and skewness.

# %% [markdown]
# ## Mean
# -  The statistical mean refers to the mean or average that is used to derive the central tendency of the data in question. It is determined by adding all the data points in a population and then dividing the total by the number of points. The resulting number is known as the mean or the average.

# %%
from IPython.display import Image
Image(filename='D:/images/mean.jpg')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
l=[1,2,3,4,5,6,7,8]
sns.distplot(l);
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
population=np.random.randint(10,20,1000)
sample=np.random.choice(a=population, size=100)
pop_mean=population.mean()
sample_mean=sample.mean()
print("population Mean=",pop_mean)
print("sample Mean=",sample_mean)
# Out:
# population Mean= 14.505
# sample Mean= 14.91

# %% [markdown]
# # median

# %%
l=[1,3,2,4,5,7,8]
median_val=np.median(l)
print(median_val)
# Out:
# 4.0

# %%
from IPython.display import Image
Image(filename='D:/images/median.jpg')

# %% [markdown]
# ## mode

# %%
from IPython.display import Image
Image(filename='D:/images/mode.jpg')

# %%
l=[1,2,3,4,4,6,7,7,5,9]
from scipy import stats
mode1=stats.mode(l)
print(mode1)
# Out:
# ModeResult(mode=array([4]), count=array([2]))

# %%
from IPython.display import Image
Image(filename='D:/images/stand1.png')

# %%
l=[1,2,3,4,5,6,7,8,9]
std1=np.std(l)
print(std1)
# Out:
# 2.581988897471611

# %%
from IPython.display import Image
Image(filename='D:/images/standard2.gif')
